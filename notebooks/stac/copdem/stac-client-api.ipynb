# %%
import sys
import pystac_client

# %%
sys.path.append("../../..")

# %%
from cdseutils.utils import BBox

# %%
endpoint_url = "https://catalogue.dataspace.copernicus.eu/stac"

# %%
collection = "COP-DEM"

# %%
bbox = BBox(
    left=16.50,
    south=40.53,
    right=16.85,
    north=40.72,
)
bbox
# Out:
# BBox(left=16.5, south=40.53, right=16.85, north=40.72)

# %%
client = pystac_client.Client.open(endpoint_url)
client.add_conforms_to("FILTER")

# %%
list(client.get_all_collections())
# Out:
# [<CollectionClient id=SUOMI-NPP>,
#  <CollectionClient id=LANDSAT-7>,
#  <CollectionClient id=COP-DEM>,
#  <CollectionClient id=LANDSAT-5>,
#  <CollectionClient id=S2GLC>,
#  <CollectionClient id=TERRAAQUA>,
#  <CollectionClient id=SMOS>,
#  <CollectionClient id=GLOBAL-MOSAICS>,
#  <CollectionClient id=SENTINEL-5P>,
#  <CollectionClient id=SENTINEL-1-RTC>,
#  <CollectionClient id=CCM>,
#  <CollectionClient id=ENVISAT>,
#  <CollectionClient id=LANDSAT-8-ESA>,
#  <CollectionClient id=SENTINEL-1>,
#  <CollectionClient id=SENTINEL-2>,
#  <CollectionClient id=CLMS>,
#  <CollectionClient id=SENTINEL-3>,
#  <CollectionClient id=SENTINEL-6>,
#  <CollectionClient id=LANDSAT-8>,
#  <CollectionClient id=LANDSAT-9>,
#  <CollectionClient id=TERRA>]

# %%
search = client.search(
    collections=[collection],
    bbox=bbox,
    # max_items=10,
)

# %%
list(search.items())
# Out:
# [<Item id=DEM1_SAR_DTE_90_20110415T164917_20140317T164937_ADS_000000_1702>,
#  <Item id=DEM1_SAR_DGE_90_20110415T164917_20140317T164937_ADS_000000_1700>,
#  <Item id=DEM1_SAR_DGE_30_20110415T164917_20140317T164937_ADS_000000_NzO0>,
#  <Item id=DEM1_SAR_DTE_30_20110415T164917_20140317T164937_ADS_000000_GxKw>]

# %%
ids = [item.id for item in search.items()]
ids
# Out:
# ['DEM1_SAR_DTE_90_20110415T164917_20140317T164937_ADS_000000_1702',
#  'DEM1_SAR_DGE_30_20110415T164917_20140317T164937_ADS_000000_NzO0',
#  'DEM1_SAR_DGE_90_20110415T164917_20140317T164937_ADS_000000_1700',
#  'DEM1_SAR_DTE_30_20110415T164917_20140317T164937_ADS_000000_GxKw']

# %%
filter = {  # noqa: A001
    "op": "=",
    "args": [
        {"property": "productType"},
        "DGE_90",
    ],
}

# %%
dged_search = client.search(
    collections=[collection],
    filter=filter,
    bbox=bbox,
    # max_items=10,
)

# %%
list(dged_search.items())
# Out:
# [<Item id=DEM1_SAR_DGE_90_20110415T164917_20140317T164937_ADS_000000_1700>]

# %%
items = list(dged_search.items())

# %%
item = items[0]

# %%
item
# Out:
# <Item id=DEM1_SAR_DGE_90_20110415T164917_20140317T164937_ADS_000000_1700>

# %%
item.assets["QUICKLOOK"]
# Out:
# <Asset href=https://catalogue.dataspace.copernicus.eu/odata/v1/Assets(1aeee18c-a979-416d-b8f3-209f36e01b0d)/$value>

# %%
asset = item.assets["PRODUCT"]
asset
# Out:
# <Asset href=https://catalogue.dataspace.copernicus.eu/odata/v1/Products(f404306f-a8b3-5164-8a90-991484c9588c)/$value>

# %%
asset.href
# Out:
# 'https://catalogue.dataspace.copernicus.eu/odata/v1/Products(f404306f-a8b3-5164-8a90-991484c9588c)/$value'

# %%
asset.extra_fields["alternate"]["s3"]
# Out:
# {'href': '/eodata/auxdata/CopDEM/COP-DEM_GLO-90-DGED/DEM1_SAR_DGE_90_20110415T164917_20140317T164937_ADS_000000_1700.DEM',
#  'storage:platform': 'CLOUDFERRO',
#  'storage:region': 'waw',
#  'storage:requester_pays': False,
#  'storage:tier': 'Online'}
